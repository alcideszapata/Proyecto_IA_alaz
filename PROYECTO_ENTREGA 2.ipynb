# %% [markdown]
# # **Clasificación de la cobertura terrestre de la UE**
#
# En el marco de nuestro proyecto de análisis de datos, es fundamental mantener un registro claro y conciso de los avances realizados. Este informe proporciona una visión general de las etapas iniciales de nuestro trabajo, destacando los hitos más relevantes y los desafíos encontrados hasta el momento.

# %% [markdown]
# ## **OEMC Hackathon: EU Land Cover Classification, Follow this link:**
#
# https://www.kaggle.com/competitions/oemc-hackathon-eu-land-cover-classification/data, register for the task and download the data.
#
# In particular, understand:
#
# The machine learning task they define (what they want to predict)
# How the data is provided
# The structure and relation between the files train.csv, weather_train.csv and building_metadata.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# utilizamos la biblioteca Pandas para cargar y manipular datos de un archivo CSV ubicado en una ruta específica en Google Drive.

# %%
import os

os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Entrega2/kaggle'

# %%
# %CD
# Out:
# UsageError: Line magic function `%CD` not found.

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
import os

os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Entrega2/kaggle'

# %% [markdown]
# cambiar el directorio de trabajo actual a la ruta especificada

# %%
# %cd /content/drive/MyDrive/Entrega2/kaggle
# Out:
# /content/drive/MyDrive/Entrega2/kaggle

# %% [markdown]
# !ls mostrará los contenidos del directorio actual.

# %%
# !ls
# Out:
# kaggle.json  land_cover

# %% [markdown]
# descargar los datos de una competición específica llamada "oemc-hackathon-eu-land-cover-classification"

# %%
# !kaggle competitions download -c oemc-hackathon-eu-land-cover-classification
# Out:
# oemc-hackathon-eu-land-cover-classification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# para crear un directorio llamado "land_cover" y luego mover un archivo llamado "oemc-hackathon-eu-land-cover-classification.zip"

# %%
# !mkdir land_cover
# !mv oemc-hackathon-eu-land-cover-classification.zip land_cover
# Out:
# mkdir: cannot create directory ‘land_cover’: File exists

# %%
# %cd land_cover/
# Out:
# /content/drive/MyDrive/Entrega2/kaggle/land_cover

# %% [markdown]
# descomprimir (extraer) el contenido del archivo ZIP llamado "oemc-hackathon-eu-land-cover-classification.zip"

# %%
# !unzip oemc-hackathon-eu-land-cover-classification.zip
# Out:
# Archive:  oemc-hackathon-eu-land-cover-classification.zip
# replace sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# leer el archivo train.csv

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/Entrega2/kaggle/land_cover/train.csv')
train.index = pd.to_datetime(train.sample_id)
train.drop('sample_id', 1, inplace=True)
train
# Out:
# <ipython-input-43-c028aaac3120>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   train.drop('sample_id', 1, inplace=True)
#                                land_cover  \
# sample_id
# 1970-01-01 00:00:00.000000000          16
# 1970-01-01 00:00:00.000000001          10
# 1970-01-01 00:00:00.000000002          15
# 1970-01-01 00:00:00.000000003          16
# 1970-01-01 00:00:00.000000004          58
# ...                                   ...
# 1970-01-01 00:00:00.000042232          16
# 1970-01-01 00:00:00.000042233          71
# 1970-01-01 00:00:00.000042234          16
# 1970-01-01 00:00:00.000042235           4
# 1970-01-01 00:00:00.000042236          59
#
#                                                      land_cover_label  year  \
# sample_id
# 1970-01-01 00:00:00.000000000      Grassland without tree/shrub cover  2006
# 1970-01-01 00:00:00.000000001                     Coniferous woodland  2006
# 1970-01-01 00:00:00.000000002  Grassland with sparse tree/shrub cover  2018
# 1970-01-01 00:00:00.000000003      Grassland without tree/shrub cover  2006
# 1970-01-01 00:00:00.000000004        Shrubland with sparse tree cover  2012
# ...                                                               ...   ...
# 1970-01-01 00:00:00.000042232      Grassland without tree/shrub cover  2009
# 1970-01-01 00:00:00.000042233                               Vineyards  2006
# 1970-01-01 00:00:00.000042234      Grassland without tree/shrub cover  2006
# 1970-01-01 00:00:00.000042235                    Broadleaved woodland  2015
# 1970-01-01 00:00:00.000042236            Shrubland without tree cover  2015
#
#                                evi_mod13q1.stl.trend_p90_250m_jan01_feb28  \
# sample_id
# 1970-01-01 00:00:00.000000000                                      3630.0
# 1970-01-01 00:00:00.000000001                                      2851.0
# 1970-01-01 00:00:00.000000002                                      3973.0
# 1970-01-01 00:00:00.000000003                                      4401.0
# 1970-01-01 00:00:00.000000004                                      4330.0
# ...                                                                   ...
# 1970-01-01 00:00:00.000042232                                      3267.0
# 1970-01-01 00:00:00.000042233                                      3868.0
# 1970-01-01 00:00:00.000042234                                      5642.0
# 1970-01-01 00:00:00.000042235                                      3642.0
# 1970-01-01 00:00:00.000042236                                      1675.0
#
#                                lst_mod11a2.nighttime.trend_p50_1km_jan01_jan31  \
# sample_id
# 1970-01-01 00:00:00.000000000                                          13868.0
# 1970-01-01 00:00:00.000000001                                          13810.0
# 1970-01-01 00:00:00.000000002                                          13958.0
# 1970-01-01 00:00:00.000000003                                          13793.0
# 1970-01-01 00:00:00.000000004                                          13868.0
# ...                                                                        ...
# 1970-01-01 00:00:00.000042232                                          13753.0
# 1970-01-01 00:00:00.000042233                                          14038.0
# 1970-01-01 00:00:00.000042234                                          13832.0
# 1970-01-01 00:00:00.000042235                                          14252.0
# 1970-01-01 00:00:00.000042236                                          14199.0
#
#                                lst_mod11a2.nighttime.trend_p50_1km_feb01_feb28  \
# sample_id
# 1970-01-01 00:00:00.000000000                                          13877.0
# 1970-01-01 00:00:00.000000001                                          13815.0
# 1970-01-01 00:00:00.000000002                                          13961.0
# 1970-01-01 00:00:00.000000003                                          13796.0
# 1970-01-01 00:00:00.000000004                                          13868.0
# ...                                                                        ...
# 1970-01-01 00:00:00.000042232                                          13749.0
# 1970-01-01 00:00:00.000042233                                          14039.0
# 1970-01-01 00:00:00.000042234                                          13839.0
# 1970-01-01 00:00:00.000042235                                          14255.0
# 1970-01-01 00:00:00.000042236                                          14200.0
#
#                                lst_mod11a2.nighttime.trend_p50_1km_mar01_mar31  \
# sample_id
# 1970-01-01 00:00:00.000000000                                          13887.0
# 1970-01-01 00:00:00.000000001                                          13820.0
# 1970-01-01 00:00:00.000000002                                          13963.0
# 1970-01-01 00:00:00.000000003                                          13800.0
# 1970-01-01 00:00:00.000000004                                          13867.0
# ...                                                                        ...
# 1970-01-01 00:00:00.000042232                                          13744.0
# 1970-01-01 00:00:00.000042233                                          14041.0
# 1970-01-01 00:00:00.000042234                                          13848.0
# 1970-01-01 00:00:00.000042235                                          14258.0
# 1970-01-01 00:00:00.000042236                                          14202.0
#
#                                lst_mod11a2.nighttime.trend_p50_1km_apr01_apr30  \
# sample_id
# 1970-01-01 00:00:00.000000000                                          13897.0
# 1970-01-01 00:00:00.000000001                                          13827.0
# 1970-01-01 00:00:00.000000002                                          13964.0
# 1970-01-01 00:00:00.000000003                                          13805.0
# 1970-01-01 00:00:00.000000004                                          13866.0
# ...                                                                        ...
# 1970-01-01 00:00:00.000042232                                          13739.0
# 1970-01-01 00:00:00.000042233                                          14044.0
# 1970-01-01 00:00:00.000042234                                          13856.0
# 1970-01-01 00:00:00.000042235                                          14261.0
# 1970-01-01 00:00:00.000042236                                          14202.0
#
#                                evi_mod13q1_p90_250m_nov01_dec31  \
# sample_id
# 1970-01-01 00:00:00.000000000                            2700.0
# 1970-01-01 00:00:00.000000001                            2565.0
# 1970-01-01 00:00:00.000000002                            2650.0
# 1970-01-01 00:00:00.000000003                            3076.0
# 1970-01-01 00:00:00.000000004                            2875.0
# ...                                                         ...
# 1970-01-01 00:00:00.000042232                            1632.0
# 1970-01-01 00:00:00.000042233                            3952.0
# 1970-01-01 00:00:00.000042234                            4528.0
# 1970-01-01 00:00:00.000042235                            4788.0
# 1970-01-01 00:00:00.000042236                            2379.0
#
#                                lst_mod11a2.nighttime.trend_p50_1km_may01_may31  \
# sample_id
# 1970-01-01 00:00:00.000000000                                          13908.0
# 1970-01-01 00:00:00.000000001                                          13835.0
# 1970-01-01 00:00:00.000000002                                          13967.0
# 1970-01-01 00:00:00.000000003                                          13813.0
# 1970-01-01 00:00:00.000000004                                          13864.0
# ...                                                                        ...
# 1970-01-01 00:00:00.000042232                                          13732.0
# 1970-01-01 00:00:00.000042233                                          14049.0
# 1970-01-01 00:00:00.000042234                                          13865.0
# 1970-01-01 00:00:00.000042235                                          14264.0
# 1970-01-01 00:00:00.000042236                                          14202.0
#
#                                ...  evi_mod13q1_p50_250m_2000_2022  \
# sample_id                      ...
# 1970-01-01 00:00:00.000000000  ...                          3080.0
# 1970-01-01 00:00:00.000000001  ...                          2560.0
# 1970-01-01 00:00:00.000000002  ...                          4180.0
# 1970-01-01 00:00:00.000000003  ...                          5020.0
# 1970-01-01 00:00:00.000000004  ...                          3180.0
# ...                            ...                             ...
# 1970-01-01 00:00:00.000042232  ...                          3792.0
# 1970-01-01 00:00:00.000042233  ...                          3784.0
# 1970-01-01 00:00:00.000042234  ...                          5508.0
# 1970-01-01 00:00:00.000042235  ...                          2274.0
# 1970-01-01 00:00:00.000042236  ...                          1263.0
#
#                                evi_mod13q1_p95_250m_2000_2022  \
# sample_id
# 1970-01-01 00:00:00.000000000                          5516.0
# 1970-01-01 00:00:00.000000001                          3292.0
# 1970-01-01 00:00:00.000000002                          6372.0
# 1970-01-01 00:00:00.000000003                          7024.0
# 1970-01-01 00:00:00.000000004                          6148.0
# ...                                                       ...
# 1970-01-01 00:00:00.000042232                          5256.0
# 1970-01-01 00:00:00.000042233                          4684.0
# 1970-01-01 00:00:00.000042234                          6400.0
# 1970-01-01 00:00:00.000042235                          3800.0
# 1970-01-01 00:00:00.000042236                          1837.0
#
#                                blue_mod13q1_p95_250m_2000_2022  \
# sample_id
# 1970-01-01 00:00:00.000000000                            566.0
# 1970-01-01 00:00:00.000000001                            143.0
# 1970-01-01 00:00:00.000000002                            254.0
# 1970-01-01 00:00:00.000000003                            510.0
# 1970-01-01 00:00:00.000000004                            582.0
# ...                                                        ...
# 1970-01-01 00:00:00.000042232                            525.0
# 1970-01-01 00:00:00.000042233                            468.0
# 1970-01-01 00:00:00.000042234                            431.0
# 1970-01-01 00:00:00.000042235                            672.0
# 1970-01-01 00:00:00.000042236                           1205.0
#
#                                red_mod13q1_p50_250m_2000_2022  \
# sample_id
# 1970-01-01 00:00:00.000000000                           673.0
# 1970-01-01 00:00:00.000000001                           156.0
# 1970-01-01 00:00:00.000000002                           286.0
# 1970-01-01 00:00:00.000000003                           569.0
# 1970-01-01 00:00:00.000000004                           863.0
# ...                                                       ...
# 1970-01-01 00:00:00.000042232                           748.0
# 1970-01-01 00:00:00.000042233                           686.0
# 1970-01-01 00:00:00.000042234                           496.0
# 1970-01-01 00:00:00.000042235                           982.0
# 1970-01-01 00:00:00.000042236                          2058.0
#
#                                ndvi_mod13q1_sd_250m_2000_2022  \
# sample_id
# 1970-01-01 00:00:00.000000000                          1418.0
# 1970-01-01 00:00:00.000000001                           478.0
# 1970-01-01 00:00:00.000000002                          1225.0
# 1970-01-01 00:00:00.000000003                          1429.0
# 1970-01-01 00:00:00.000000004                          1964.0
# ...                                                       ...
# 1970-01-01 00:00:00.000042232                          1373.0
# 1970-01-01 00:00:00.000042233                           848.0
# 1970-01-01 00:00:00.000042234                           945.0
# 1970-01-01 00:00:00.000042235                          1214.0
# 1970-01-01 00:00:00.000042236                           498.0
#
#                                nir_mod13q1_sd_250m_2000_2022  \
# sample_id
# 1970-01-01 00:00:00.000000000                          537.0
# 1970-01-01 00:00:00.000000001                          348.0
# 1970-01-01 00:00:00.000000002                          891.0
# 1970-01-01 00:00:00.000000003                          796.0
# 1970-01-01 00:00:00.000000004                          850.0
# ...                                                      ...
# 1970-01-01 00:00:00.000042232                          604.0
# 1970-01-01 00:00:00.000042233                          388.0
# 1970-01-01 00:00:00.000042234                          437.0
# 1970-01-01 00:00:00.000042235                          438.0
# 1970-01-01 00:00:00.000042236                          664.0
#
#                                pop.count_ghs.jrc_m_100m  \
# sample_id
# 1970-01-01 00:00:00.000000000                       0.0
# 1970-01-01 00:00:00.000000001                       0.0
# 1970-01-01 00:00:00.000000002                       0.0
# 1970-01-01 00:00:00.000000003                      22.0
# 1970-01-01 00:00:00.000000004                      74.0
# ...                                                 ...
# 1970-01-01 00:00:00.000042232                       6.0
# 1970-01-01 00:00:00.000042233                       0.0
# 1970-01-01 00:00:00.000042234                       0.0
# 1970-01-01 00:00:00.000042235                       0.0
# 1970-01-01 00:00:00.000042236                       0.0
#
#                                cost.distance.to.coast_gedi.grass.gis_30m_2000..2018  \
# sample_id
# 1970-01-01 00:00:00.000000000                                              141.0
# 1970-01-01 00:00:00.000000001                                              614.0
# 1970-01-01 00:00:00.000000002                                              606.0
# 1970-01-01 00:00:00.000000003                                              820.0
# 1970-01-01 00:00:00.000000004                                              191.0
# ...                                                                          ...
# 1970-01-01 00:00:00.000042232                                              165.0
# 1970-01-01 00:00:00.000042233                                               26.0
# 1970-01-01 00:00:00.000042234                                                6.0
# 1970-01-01 00:00:00.000042235                                              496.0
# 1970-01-01 00:00:00.000042236                                              590.0
#
#                                slope.percent_gedi.eml_m_30m_2000_2018  \
# sample_id
# 1970-01-01 00:00:00.000000000                                     7.0
# 1970-01-01 00:00:00.000000001                                    55.0
# 1970-01-01 00:00:00.000000002                                    13.0
# 1970-01-01 00:00:00.000000003                                     8.0
# 1970-01-01 00:00:00.000000004                                    19.0
# ...                                                               ...
# 1970-01-01 00:00:00.000042232                                    10.0
# 1970-01-01 00:00:00.000042233                                     3.0
# 1970-01-01 00:00:00.000042234                                     0.0
# 1970-01-01 00:00:00.000042235                                    18.0
# 1970-01-01 00:00:00.000042236                                    25.0
#
#                                elev.lowestmode_gedi.eml_m_30m_2000_2018
# sample_id
# 1970-01-01 00:00:00.000000000                                     151.0
# 1970-01-01 00:00:00.000000001                                     683.0
# 1970-01-01 00:00:00.000000002                                     336.0
# 1970-01-01 00:00:00.000000003                                     688.0
# 1970-01-01 00:00:00.000000004                                     221.0
# ...                                                                 ...
# 1970-01-01 00:00:00.000042232                                     270.0
# 1970-01-01 00:00:00.000042233                                      95.0
# 1970-01-01 00:00:00.000042234                                      43.0
# 1970-01-01 00:00:00.000042235                                     416.0
# 1970-01-01 00:00:00.000042236                                     262.0
#
# [42237 rows x 419 columns]

# %%
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission
# Out:
#        sample_id  land_cover
# 0              0          68
# 1              1           1
# 2              2           6
# 3              3          33
# 4              4          44
# ...          ...         ...
# 42266      42266          19
# 42267      42267          29
# 42268      42268           3
# 42269      42269          12
# 42270      42270           8
#
# [42271 rows x 2 columns]

# %%
import pandas as pd
test = pd.read_csv('test.csv')

test
# Out:
#        sample_id  year  evi_mod13q1.stl.trend_p90_250m_jan01_feb28  \
# 0              0  2018                                      2759.0
# 1              1  2012                                      4085.0
# 2              2  2018                                      4169.0
# 3              3  2012                                      2783.0
# 4              4  2009                                      3915.0
# ...          ...   ...                                         ...
# 42266      42266  2012                                      4960.0
# 42267      42267  2015                                      3974.0
# 42268      42268  2009                                      3753.0
# 42269      42269  2018                                      5632.0
# 42270      42270  2018                                      5696.0
#
#        lst_mod11a2.nighttime.trend_p50_1km_jan01_jan31  \
# 0                                              14005.0
# 1                                              14007.0
# 2                                              14024.0
# 3                                              14008.0
# 4                                              13825.0
# ...                                                ...
# 42266                                          13955.0
# 42267                                          13892.0
# 42268                                          13971.0
# 42269                                          14109.0
# 42270                                          13914.0
#
#        lst_mod11a2.nighttime.trend_p50_1km_feb01_feb28  \
# 0                                              14001.0
# 1                                              14006.0
# 2                                              14026.0
# 3                                              14006.0
# 4                                              13826.0
# ...                                                ...
# 42266                                          13952.0
# 42267                                          13893.0
# 42268                                          13971.0
# 42269                                          14110.0
# 42270                                          13916.0
#
#        lst_mod11a2.nighttime.trend_p50_1km_mar01_mar31  \
# 0                                              13998.0
# 1                                              14004.0
# 2                                              14028.0
# 3                                              14004.0
# 4                                              13826.0
# ...                                                ...
# 42266                                          13948.0
# 42267                                          13895.0
# 42268                                          13972.0
# 42269                                          14111.0
# 42270                                          13917.0
#
#        lst_mod11a2.nighttime.trend_p50_1km_apr01_apr30  \
# 0                                              13997.0
# 1                                              14002.0
# 2                                              14030.0
# 3                                              14003.0
# 4                                              13827.0
# ...                                                ...
# 42266                                          13944.0
# 42267                                          13897.0
# 42268                                          13973.0
# 42269                                          14113.0
# 42270                                          13919.0
#
#        evi_mod13q1_p90_250m_nov01_dec31  \
# 0                                3435.0
# 1                                3764.0
# 2                                2684.0
# 3                                5791.0
# 4                                2322.0
# ...                                 ...
# 42266                            3259.0
# 42267                            2333.0
# 42268                            3448.0
# 42269                            5954.0
# 42270                            6418.0
#
#        lst_mod11a2.nighttime.trend_p50_1km_may01_may31  \
# 0                                              13996.0
# 1                                              13998.0
# 2                                              14031.0
# 3                                              14002.0
# 4                                              13828.0
# ...                                                ...
# 42266                                          13939.0
# 42267                                          13898.0
# 42268                                          13974.0
# 42269                                          14114.0
# 42270                                          13922.0
#
#        evi_mod13q1_p90_250m_sep01_oct31  ...  evi_mod13q1_p50_250m_2000_2022  \
# 0                                2272.0  ...                          1814.0
# 1                                2454.0  ...                          2178.0
# 2                                2536.0  ...                          4296.0
# 3                                3132.0  ...                          1795.0
# 4                                2242.0  ...                          4784.0
# ...                                 ...  ...                             ...
# 42266                            3846.0  ...                          2882.0
# 42267                            2761.0  ...                          2930.0
# 42268                            3283.0  ...                          3210.0
# 42269                            4779.0  ...                          5744.0
# 42270                            5428.0  ...                          3336.0
#
#        evi_mod13q1_p95_250m_2000_2022  blue_mod13q1_p95_250m_2000_2022  \
# 0                              3230.0                            929.0
# 1                              5968.0                            676.0
# 2                              6164.0                            366.0
# 3                              2256.0                            775.0
# 4                              5660.0                            256.0
# ...                               ...                              ...
# 42266                          5952.0                            534.0
# 42267                          5572.0                            343.0
# 42268                          4096.0                            302.0
# 42269                          6416.0                            487.0
# 42270                          6456.0                            565.0
#
#        red_mod13q1_p50_250m_2000_2022  ndvi_mod13q1_sd_250m_2000_2022  \
# 0                              1476.0                           845.0
# 1                               768.0                          1932.0
# 2                               453.0                          1442.0
# 3                              1490.0                           750.0
# 4                               267.0                          1410.0
# ...                               ...                             ...
# 42266                           829.0                          1549.0
# 42267                           387.0                          1357.0
# 42268                           388.0                           487.0
# 42269                           486.0                          1154.0
# 42270                           765.0                          1527.0
#
#        nir_mod13q1_sd_250m_2000_2022  pop.count_ghs.jrc_m_100m  \
# 0                              596.0                       0.0
# 1                              946.0                       0.0
# 2                              909.0                       0.0
# 3                              418.0                       0.0
# 4                              828.0                       0.0
# ...                              ...                       ...
# 42266                          733.0                       5.0
# 42267                          808.0                       0.0
# 42268                          592.0                       0.0
# 42269                          727.0                       4.0
# 42270                          857.0                       0.0
#
#        cost.distance.to.coast_gedi.grass.gis_30m_2000..2018  \
# 0                                                 1039.0
# 1                                                  199.0
# 2                                                  535.0
# 3                                                 1049.0
# 4                                                 1032.0
# ...                                                  ...
# 42266                                               20.0
# 42267                                              275.0
# 42268                                              494.0
# 42269                                               12.0
# 42270                                                1.0
#
#        slope.percent_gedi.eml_m_30m_2000_2018  \
# 0                                         5.0
# 1                                         3.0
# 2                                         6.0
# 3                                         4.0
# 4                                        25.0
# ...                                       ...
# 42266                                     4.0
# 42267                                    15.0
# 42268                                    19.0
# 42269                                    19.0
# 42270                                     3.0
#
#        elev.lowestmode_gedi.eml_m_30m_2000_2018
# 0                                         833.0
# 1                                         199.0
# 2                                         135.0
# 3                                         742.0
# 4                                         758.0
# ...                                         ...
# 42266                                      69.0
# 42267                                     275.0
# 42268                                     623.0
# 42269                                     103.0
# 42270                                      42.0
#
# [42271 rows x 418 columns]
